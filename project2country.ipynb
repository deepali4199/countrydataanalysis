# %%
#Questions 
#which country has the highest population
#what is the capital of the country with highest population
#which country has the least population
#what is the capital of the country with least population
#give me top 5 countries with highest democratic score
#how many total regions are there
#how many countries lie in Eastern Europe region
#who is the political leader of the 2nd highest populated country
#how many countries are there whoes political leaders are unknown
#how many country have Republic in their full name
#which country in african region has highest population

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(r"Countries.csv")

# %%
df
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# 1          Albanian lek            Tirana     Southern Europe    Europe
# 2        Algerian dinar           Algiers     Northern Africa    Africa
# 3                  Euro  Andorra la Vella     Southern Europe    Europe
# 4        Angolan kwanza            Luanda       Middle Africa    Africa
# ..                  ...               ...                 ...       ...
# 189     Vietnamese dong             Hanoi  South-Eastern Asia      Asia
# 190  Israeli new shekel          Ramallah        Western Asia      Asia
# 191         Yemeni rial            Sana'a        Western Asia      Asia
# 192  New Zambian kwacha            Lusaka      Eastern Africa    Africa
# 193         U.S. dollar            Harare      Eastern Africa    Africa
#
#          demonym   latitude   longitude  agricultural_land  ...  population  \
# 0         Afghan  33.000000   65.000000           383560.0  ...    41128771
# 1       Albanian  41.000000   20.000000            11655.5  ...     2775634
# 2       Algerian  28.000000    3.000000           413588.0  ...    44903225
# 3       Andorran  42.500000    1.500000              187.2  ...       79824
# 4        Angolan -12.500000   18.500000           569525.0  ...    35588987
# ..           ...        ...         ...                ...  ...         ...
# 189   Vietnamese  16.166667  107.833333           123600.0  ...    98186856
# 190  Palestinian  31.900000   35.200000             4449.0  ...     5043612
# 191       Yemeni  15.000000   48.000000           234520.0  ...    33696614
# 192      Zambian -15.000000   30.000000           238360.0  ...    20017675
# 193   Zimbabwean -20.000000   30.000000           162000.0  ...    16320537
#
#      women_parliament_seats_pct  rural_population  urban_population  press  \
# 0                      27.01610          30181937          10946834   2.14
# 1                      35.71430           1004807           1770827   2.62
# 2                       8.10811          11328186          33575039   1.71
# 3                      46.42860              9730             70094   3.17
# 4                      33.63640          11359649          24229338   2.24
# ..                          ...               ...               ...    ...
# 189                    30.26050          60123739          38063117   1.04
# 190                         NaN           1145354           3898258   1.75
# 191                     0.00000          20491585          13205029   1.27
# 192                    15.06020          10857387           9160288   2.15
# 193                    30.56600          11033499           5287038   1.85
#
#      democracy_score  democracy_type  median_age       political_leader  \
# 0               2.97   Authoritarian        12.9           Ashraf Ghani
# 1               5.98   Hybrid regime        33.7               Edi Rama
# 2               3.50   Authoritarian        24.0   Abdelmadjid Tebboune
# 3               0.00         Unknown        38.9    Xavier Espot Zamora
# 4               3.62   Authoritarian        12.4          João Lourenço
# ..               ...             ...         ...                    ...
# 189             3.08   Authoritarian        28.4       Nguyễn Phú Trọng
# 190             4.39   Hybrid regime        15.4                    NaN
# 191             1.95   Authoritarian        14.8  Abdrabbuh Mansur Hadi
# 192             5.61   Hybrid regime        13.2            Edgar Lungu
# 193             3.16   Authoritarian        14.2     Emmerson Mnangagwa
#
#                                         title
# 0                                   President
# 1                              Prime Minister
# 2                                   President
# 3                          Head of Government
# 4                                   President
# ..                                        ...
# 189  General Secretary of the Communist Party
# 190                                       NaN
# 191                                 President
# 192                                 President
# 193                                 President
#
# [194 rows x 64 columns]

# %%
df.shape
# Out:
# (194, 64)

# %%
df["population"].max()
# Out:
# 1417173173

# %%
df.loc[df["population"]== df["population"].max()]
# Out:
#    country       country_long      currency capital_city         region  \
# 75   India  Republic of India  Indian rupee    New Delhi  Southern Asia
#
#    continent demonym  latitude  longitude  agricultural_land  ...  population  \
# 75      Asia  Indian      20.0       77.0          1790450.0  ...  1417173173
#
#     women_parliament_seats_pct  rural_population  urban_population  press  \
# 75                     14.9446         908804812         508368361   1.71
#
#     democracy_score    democracy_type  median_age  political_leader  \
# 75             7.23  Flawed democracy        23.9     Narendra Modi
#
#              title
# 75  Prime Minister
#
# [1 rows x 64 columns]

# %%
df.loc[df["population"]== df["population"].max()]["country"]
# Out:
# 75    India
# Name: country, dtype: object

# %%
df.loc[df["population"]== df["population"].max()]["capital_city"]
# Out:
# 75    New Delhi
# Name: capital_city, dtype: object

# %%
df.loc[df["population"]== df["population"].min()]["country"]
# Out:
# 179    Tuvalu
# Name: country, dtype: object

# %%
df.loc[df["population"]== df["population"].min()]["capital_city"]
# Out:
# 179    Funafuti
# Name: capital_city, dtype: object

# %%
dummydf = df.sort_values(by = "democracy_score",ascending = False)
dummydf["country"].head()
# Out:
# 127         Norway
# 74         Iceland
# 164         Sweden
# 122    New Zealand
# 46         Denmark
# Name: country, dtype: object

# %%
dummydf[dummydf['country']== "India"]["democracy_score"]
# Out:
# 75    7.23
# Name: democracy_score, dtype: float64

# %%
df["region"].value_counts()
# Out:
# region
# Western Asia                 17
# Eastern Africa               17
# Western Africa               16
# Southern Europe              15
# Caribbean                    13
# South America                12
# South-Eastern Asia           11
# Northern Europe              10
# Middle Africa                10
# Eastern Europe               10
# Southern Asia                 9
# Western Europe                9
# Central America               8
# Northern Africa               6
# Southern Africa               5
# Eastern Asia                  5
# Central Asia                  5
# Micronesia                    5
# Melanesia                     4
# Polynesia                     3
# Australia and New Zealand     2
# Northern America              2
# Name: count, dtype: int64

# %%
df["region"].value_counts().count()
# Out:
# 22

# %%
df["region"].value_counts()["Eastern Europe"]
# Out:
# 10

# %%
dummydf.sort_values(by = "population", ascending= False).iloc[1]
# Out:
# country                                                China
# country_long                      People's Republic of China
# currency                                        Chinese yuan
# capital_city                                         Beijing
# region                                          Eastern Asia
#                                       ...
# democracy_score                                         3.32
# democracy_type                                 Authoritarian
# median_age                                              34.5
# political_leader                                  Xi Jinping
# title               General Secretary of the Communist Party
# Name: 34, Length: 64, dtype: object

# %%
dummydf.sort_values(by = "population", ascending= False).iloc[1]["political_leader"]
# Out:
# 'Xi Jinping'

# %%
df[df["population"]==df["population"].nlargest(2).iloc[1]]["political_leader"]
# Out:
# 75    Narendra Modi
# Name: political_leader, dtype: object

# %%
df[df["population"]==df["population"].nlargest(1).iloc[0]]["political_leader"]
# Out:
# 75    Narendra Modi
# Name: political_leader, dtype: object

# %%
df.loc[df["political_leader"].isna()]
df
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# 1          Albanian lek            Tirana     Southern Europe    Europe
# 2        Algerian dinar           Algiers     Northern Africa    Africa
# 3                  Euro  Andorra la Vella     Southern Europe    Europe
# 4        Angolan kwanza            Luanda       Middle Africa    Africa
# ..                  ...               ...                 ...       ...
# 189     Vietnamese dong             Hanoi  South-Eastern Asia      Asia
# 190  Israeli new shekel          Ramallah        Western Asia      Asia
# 191         Yemeni rial            Sana'a        Western Asia      Asia
# 192  New Zambian kwacha            Lusaka      Eastern Africa    Africa
# 193         U.S. dollar            Harare      Eastern Africa    Africa
#
#          demonym   latitude   longitude  agricultural_land  ...  population  \
# 0         Afghan  33.000000   65.000000           383560.0  ...    41128771
# 1       Albanian  41.000000   20.000000            11655.5  ...     2775634
# 2       Algerian  28.000000    3.000000           413588.0  ...    44903225
# 3       Andorran  42.500000    1.500000              187.2  ...       79824
# 4        Angolan -12.500000   18.500000           569525.0  ...    35588987
# ..           ...        ...         ...                ...  ...         ...
# 189   Vietnamese  16.166667  107.833333           123600.0  ...    98186856
# 190  Palestinian  31.900000   35.200000             4449.0  ...     5043612
# 191       Yemeni  15.000000   48.000000           234520.0  ...    33696614
# 192      Zambian -15.000000   30.000000           238360.0  ...    20017675
# 193   Zimbabwean -20.000000   30.000000           162000.0  ...    16320537
#
#      women_parliament_seats_pct  rural_population  urban_population  press  \
# 0                      27.01610          30181937          10946834   2.14
# 1                      35.71430           1004807           1770827   2.62
# 2                       8.10811          11328186          33575039   1.71
# 3                      46.42860              9730             70094   3.17
# 4                      33.63640          11359649          24229338   2.24
# ..                          ...               ...               ...    ...
# 189                    30.26050          60123739          38063117   1.04
# 190                         NaN           1145354           3898258   1.75
# 191                     0.00000          20491585          13205029   1.27
# 192                    15.06020          10857387           9160288   2.15
# 193                    30.56600          11033499           5287038   1.85
#
#      democracy_score  democracy_type  median_age       political_leader  \
# 0               2.97   Authoritarian        12.9           Ashraf Ghani
# 1               5.98   Hybrid regime        33.7               Edi Rama
# 2               3.50   Authoritarian        24.0   Abdelmadjid Tebboune
# 3               0.00         Unknown        38.9    Xavier Espot Zamora
# 4               3.62   Authoritarian        12.4          João Lourenço
# ..               ...             ...         ...                    ...
# 189             3.08   Authoritarian        28.4       Nguyễn Phú Trọng
# 190             4.39   Hybrid regime        15.4                    NaN
# 191             1.95   Authoritarian        14.8  Abdrabbuh Mansur Hadi
# 192             5.61   Hybrid regime        13.2            Edgar Lungu
# 193             3.16   Authoritarian        14.2     Emmerson Mnangagwa
#
#                                         title
# 0                                   President
# 1                              Prime Minister
# 2                                   President
# 3                          Head of Government
# 4                                   President
# ..                                        ...
# 189  General Secretary of the Communist Party
# 190                                       NaN
# 191                                 President
# 192                                 President
# 193                                 President
#
# [194 rows x 64 columns]

# %%
df.loc[df["political_leader"].isna()]["country"].count()
# Out:
# 7

# %%
df["country_long"]
# Out:
# 0                 Islamic State of Afghanistan
# 1                          Republic of Albania
# 2      People's Democratic Republic of Algeria
# 3                      Principality of Andorra
# 4                  People's Republic of Angola
#                         ...
# 189              Socialist Republic of Vietnam
# 190                         West Bank and Gaza
# 191                          Republic of Yemen
# 192                         Republic of Zambia
# 193                       Republic of Zimbabwe
# Name: country_long, Length: 194, dtype: object

# %%
count =0
def counting(txt):
    global count
    if "republic" in txt:
        count+=1
    return txt

# %%
df["country_long"]= df["country_long"].apply(counting)
count
# Out:
# 0

# %%
count2 = df["country_long"].str.count("Republic").sum()
count2
# Out:
# 125

# %%
df[df["country_long"].str.contains("Republic")].head()
# Out:
#      country                             country_long        currency  \
# 1    Albania                      Republic of Albania    Albanian lek
# 2    Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 4     Angola              People's Republic of Angola  Angolan kwanza
# 6  Argentina                       Argentine Republic  Argentine peso
# 7    Armenia                      Republic of Armenia   Armenian dram
#
#    capital_city           region continent    demonym  latitude  longitude  \
# 1        Tirana  Southern Europe    Europe   Albanian      41.0       20.0
# 2       Algiers  Northern Africa    Africa   Algerian      28.0        3.0
# 4        Luanda    Middle Africa    Africa    Angolan     -12.5       18.5
# 6  Buenos Aires    South America  Americas  Argentine     -34.0      -64.0
# 7       Yerevan     Western Asia      Asia   Armenian      40.0       45.0
#
#    agricultural_land  ...  population  women_parliament_seats_pct  \
# 1            11655.5  ...     2775634                    35.71430
# 2           413588.0  ...    44903225                     8.10811
# 4           569525.0  ...    35588987                    33.63640
# 6          1083820.0  ...    46234830                    44.74710
# 7            16760.0  ...     2780469                    35.51400
#
#    rural_population  urban_population  press  democracy_score  \
# 1           1004807           1770827   2.62             5.98
# 2          11328186          33575039   1.71             3.50
# 4          11359649          24229338   2.24             3.62
# 6           3538352          42696478   2.76             7.02
# 7           1012841           1767628   2.70             4.79
#
#      democracy_type  median_age      political_leader           title
# 1     Hybrid regime        33.7              Edi Rama  Prime Minister
# 2     Authoritarian        24.0  Abdelmadjid Tebboune       President
# 4     Authoritarian        12.4         João Lourenço       President
# 6  Flawed democracy        27.6     Alberto Fernández       President
# 7     Hybrid regime        30.8       Nikol Pashinyan  Prime Minister
#
# [5 rows x 64 columns]

# %%
dummy=df[df["continent"]== "Africa"]
dummy["population"].max()
# Out:
# 218541212

# %%
dummy[dummy["population"]== dummy["population"].max()]
# Out:
#      country                 country_long        currency capital_city  \
# 125  Nigeria  Federal Republic of Nigeria  Nigerian naira        Abuja
#
#              region continent   demonym  latitude  longitude  \
# 125  Western Africa    Africa  Nigerian      10.0        8.0
#
#      agricultural_land  ...  population  women_parliament_seats_pct  \
# 125           694500.0  ...   218541212                     3.61111
#
#      rural_population  urban_population  press  democracy_score  \
# 125         101575770         116965442   2.14             4.44
#
#      democracy_type  median_age  political_leader      title
# 125   Hybrid regime        13.2  Muhammadu Buhari  President
#
# [1 rows x 64 columns]

# %%
dummy[dummy["population"]== dummy["population"].max()]["country"]
# Out:
# 125    Nigeria
# Name: country, dtype: object
